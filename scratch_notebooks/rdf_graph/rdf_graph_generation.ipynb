# %% [markdown]
# # Intialize RDFGraph class
# This was originally intended to operate on pulled abstracts from the arxiv and pubmed APIs. The model is now adjusted to operate directly on full text. Simply pull out the full text into the nested list.
#
# There are several parameters that need tuning in the RDFGraph, for now, we use the default parameters that worked best for the DTRA model.

# %%
# change base dir to multivac dir
import os
import json
os.chdir('/Users/taylor_bolt/PycharmProjects/multivac/multivac')

# Pull in full text and put into nested list
article_json = json.load(open('data/cleanedArticles-03042019.json'))
all_article_text = [ article['text'] for article in article_json.values() ]

# Initialize RDFGraph object
from src.data.rdf_graph import RDFGraph
rdf_obj = RDFGraph(all_article_text[:100]) # subset to 100 articles for now

# %% [markdown]
# # Extract relation tuples from full text w/corenlp

# %%
'''The Stanford CoreNLP runs in Java. However, the 'pycorenlp' is a python
wrapper to the CoreNLP program.  To use it, you need to download the
Stanford coreNLP program library on to your computer, plus an installation
of Java 8+ to run the program. To download go here:
https://stanfordnlp.github.io/CoreNLP/. Before you can call the CoreNLP
program from 'pycorenlp', you need to have the Stanford CoreNLP server
running. To do that navigate to the downloaded CoreNLP folder on your
terminal and run the following command:

java -mx4g -cp '*' edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 500000

Once you've done that, you should be ready to go! If you run into problems
running the CoreNLP server, see the following webpage
(https://stanfordnlp.github.io/CoreNLP/corenlp-server.html#getting-started)'''

rdf_obj.extract_raw_tuples()
# Out:
# 0 articles out of 100 processed
# Article is too large for parser, need to split up
# Article is too large for parser, need to split up
# Article is too large for parser, need to split up
# Article is too large for parser, need to split up
# Article is too large for parser, need to split up
# {0: [[('Recurrent epidemics',
#     'be in',
#     'small world networks J. A. Verdascaa')],
#   [('patterns', 'be with', 'slightly irregular periods')],
#   [('importance', 'be in', 'dynamics of childhood diseases')],
#   [('50', 'in', 'Bartlett')],
#   [('relative ﬂuctuations', 'lead to', 'Citation')],
#   [('spatial correlations', 'greatly enhance', 'stochastic ﬂuctuations')],
#   [('small world networks', 'be with', 'SIR')],
#   [('square lattice', 'be with', 'small world interaction rules')],
#   [('increase', 'be in', 'spatial correlations')],
#   [('simple deterministic models', 'be with', 'seasonal forcing'),
#    ('pre-vaccination pattern',
#     'be',
# ...

# %% [markdown]
# ### Load in previosly run rdf_obj (the above process takes a couple hours)

# %%
import pickle
rdf_obj = pickle.load(open('data/rdf_obj_temp.pickle','rb'))

# %%
# pre-process extracted tuples
print('\nPreprocessing raw relation triples')
rdf_obj.preprocess_raw_tuples()

# cluster all entities using fast
# agglomerative clustering and string distance
print('\nClustering entities from relation triples')
rdf_obj.cluster_entities()
print('\n{} entity clusters were found'
      .format(len(rdf_obj.entity_cluster_results['cluster_members'])))


# output text files that will be used openke for knowledge graph creation
# and embedding output .txt files for openke output
from datetime import datetime
timestamp = datetime.now()
print('\nSaving final tuples to .txt files for input to OpenKE')
rdf_obj.output_to_openke(timestamp)
# Out:
# Preprocessing raw relation triples
# /Users/taylor_bolt/PycharmProjects/multivac/venv/lib/python3.7/site-packages/scipy/sparse/base.py:582: RuntimeWarning: divide by zero encountered in true_divide
#   return self.astype(np.float_)._mul_scalar(1./other)
# /Users/taylor_bolt/PycharmProjects/multivac/venv/lib/python3.7/site-packages/scipy/sparse/base.py:582: RuntimeWarning: divide by zero encountered in true_divide
#   return self.astype(np.float_)._mul_scalar(1./other)
# /Users/taylor_bolt/PycharmProjects/multivac/venv/lib/python3.7/site-packages/scipy/sparse/base.py:582: RuntimeWarning: divide by zero encountered in true_divide
#   return self.astype(np.float_)._mul_scalar(1./other)
# /Users/taylor_bolt/PycharmProjects/multivac/venv/lib/python3.7/site-packages/scipy/sparse/base.py:582: RuntimeWarning: divide by zero encountered in true_divide
#   return self.astype(np.float_)._mul_scalar(1./other)
# ...

# %%
len(rdf_obj.text)
# Out:
# 2559

# %%
rdf_obj.all_tuples[-2]
# Out:
# [[('repeated vaccination',
#    'be',
#    'Thus has discontinued recently on geographical scale')],
#  [('We', 'follow up', 'effects of vaccination in detailed manner'),
#   ('effects', 'be in', 'detailed manner')],
#  [('baits', 'locally be assign to', 'individual foxes'),
#   ('baits', 'be', 'locally assigned')],
#  [('controlled area', 'ring-like around', 'outbreak')],
#  [('ring area', 'result in', 'fewer breakouts')],
#  [('Conclusion', 'be', 'favourable')],
#  [('main reserve', 'be in', 'Europe')],
#  [('efficient oral rabies virus vaccine', 'be', 'available NumericCitation')],
#  [('huge efforts', 'be in', 'rabies control')],
#  [('regional scale', 'be in', 'central Europe')],
#  [('repeated vaccination', 'be in', 'regions')],
#  [('local outbreak', 'be in', 'non-immunised wildlife populations'),
#   ('we',
#    'develop',
#    'emergency measures designed for local outbreak in non-immunised wildlife populations')],
#  [('situation', 'be in', 'UK')],
# ...
